# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
import pandas as pd

fifa = pd.read_csv('fifa.csv')
fifa.columns = fifa.columns.str.replace(' ', '')

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value PreferredFoot Position  WeakFoot  \
# 0         FC Barcelona  €110.5M          Left       RF       4.0
# 1             Juventus     €77M         Right       ST       4.0
# 2  Paris Saint-Germain  €118.5M         Right       LW       5.0
# 3    Manchester United     €72M         Right       GK       3.0
# 4      Manchester City    €102M         Right      RCM       5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# 1          89.0         91.0     88.0      79.0       93.0        63.0
# ...

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
fifa['Value'].value_counts()[:10]
# Out:
# €1.1M    431
# €375K    372
# €425K    354
# €325K    351
# €450K    343
# €525K    338
# €350K    325
# €1.2M    324
# €400K    323
# €1M      318
# Name: Value, dtype: int64

# %%
fifa['Value'].value_counts().sort_index()[:10]
# Out:
# €0       252
# €1.1M    431
# €1.2M    324
# €1.3M    260
# €1.4M    221
# €1.5M    130
# €1.6M    154
# €1.7M    118
# €1.8M    188
# €1.9M    116
# Name: Value, dtype: int64

# %%
fifa['Value'].isna().sum()
# Out:
# 0

# %%
fifa.loc[fifa['Value'].str.contains('M'), 'ValueNumeric'] = fifa['Value'].str.extract(r'(\d+\.*\d*)', expand = False).astype('float64') * 10**6
fifa.loc[fifa['Value'].str.contains('K'), 'ValueNumeric'] = fifa['Value'].str.extract(r'(\d+\.*\d*)', expand = False).astype('float64') * 10**3
fifa.loc[fifa['Value'].str.contains('^(MK)', regex = True), 'ValueNumeric'] = fifa['Value'].str.extract(r'(\d+\.*\d*)', expand = False).astype('float64')
fifa.head()
# Out:
# C:\Users\rbarr\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value PreferredFoot Position  WeakFoot  ...  \
# 0         FC Barcelona  €110.5M          Left       RF       4.0  ...
# 1             Juventus     €77M         Right       ST       4.0  ...
# 2  Paris Saint-Germain  €118.5M         Right       LW       5.0  ...
# 3    Manchester United     €72M         Right       GK       3.0  ...
# ...

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
import scipy.stats as stats

stats.f_oneway

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

lm = ols('ValueNumeric ~ C(PreferredFoot) + C(Position)', data = fifa).fit()
table = sm.stats.anova_lm(lm)
table.index = ['PreferredFoot', 'Position', 'Residual']
table
# Out:
#                     df        sum_sq       mean_sq          F        PR(>F)
# PreferredFoot      1.0  1.560350e+14  1.560350e+14   5.058849  2.451262e-02
# Position          26.0  1.659610e+16  6.383114e+14  20.694853  1.699733e-95
# Residual       17879.0  5.514593e+17  3.084397e+13        NaN           NaN

# %%
lm2 = ols('ValueNumeric ~ C(PreferredFoot)*C(Position)', data = fifa).fit()

table = sm.stats.anova_lm(lm2)
table.index = ['PreferredFoot', 'Position', 'Interaction', 'Residual']
table
# Out:
#                     df        sum_sq       mean_sq          F        PR(>F)
# PreferredFoot      1.0  1.560350e+14  1.560350e+14   5.099413  2.394597e-02
# Position          26.0  1.659610e+16  6.383114e+14  20.860790  2.309558e-96
# Interaction       26.0  5.182140e+15  1.993131e+14   6.513793  7.422724e-23
# Residual       17853.0  5.462771e+17  3.059862e+13        NaN           NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# There is sufficient evidence to suggest that a fifa player's value depends on their preferred foot and position. 
# Furthermore, these factors have an interactive effect beyond the individual effects of preferred foot and position alone.

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
lm = ols('ValueNumeric ~ C(Nationality)', data = fifa).fit()
table = sm.stats.anova_lm(lm)
table.index = ['Nationality', 'Residual']
table
# Out:
#                   df        sum_sq       mean_sq         F         PR(>F)
# Nationality    163.0  3.339290e+16  2.048644e+14  6.805485  3.380619e-135
# Residual     17792.0  5.355897e+17  3.010284e+13       NaN            NaN

# %% [markdown]
# What is your conclusion from this ANOVA?

# %%
# There is sufficient evidence to suggest that a fifa player's value depends on their nationality.

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
missing = [i for i in fifa.index if fifa.iloc[i].isna().sum() > 0]
fifa_nomissing = fifa.drop(missing)

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
X = sm.add_constant(fifa_nomissing[['Stamina', 'SprintSpeed']])
Y = fifa_nomissing['ValueNumeric']

lm = sm.OLS(Y, X, data = fifa_nomissing).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     452.2
# Date:                Sat, 14 Sep 2019   Prob (F-statistic):          2.64e-192
# Time:                        17:06:55   Log-Likelihood:            -3.0332e+05
# No. Observations:               17907   AIC:                         6.066e+05
# Df Residuals:                   17904   BIC:                         6.067e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -3.072e+06   1.97e+05    -15.576      0.000   -3.46e+06   -2.69e+06
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# There is sufficient evidence that the model is predictive of player values (F = 452.2, p < .0001). Overall, the model 
# is able to explain 4.8% of the variability in player values. In particular, both factors have a signficant, positive 
# effect on the player's value. It seems as though a player's stamina has more than twice (2.3x) the impact of their 
# sprint speed on their value, yet these individual effects are signficant.

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
X = sm.add_constant(fifa_nomissing['Potential'])
Y = fifa_nomissing['ValueNumeric']

lm = sm.OLS(Y, X, data = fifa_nomissing).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.336
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     9073.
# Date:                Sat, 14 Sep 2019   Prob (F-statistic):               0.00
# Time:                        17:18:26   Log-Likelihood:            -3.0009e+05
# No. Observations:               17907   AIC:                         6.002e+05
# Df Residuals:                   17905   BIC:                         6.002e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.552e+07      4e+05    -88.778      0.000   -3.63e+07   -3.47e+07
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
# There is sufficient evidence that the model is predictive of player values (F = 452.2, p < .0001). Overall, the model 
# is able to explain 33.6% of the variability in player values. In particular, a player's potential has a signficant, 
# positive effect on their value. This predictor alone was able to explain a signficantly larger percent of variation in
# the player's value as compared to the previous model.

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize = (10, 10))
sns.set_style('ticks')
sns.set_context('notebook')

sns.relplot(x = 'Potential', y = 'ValueNumeric', palette = 'tab20', alpha = .2, data = fifa_nomissing)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize = (10, 10))
sns.set_style('ticks')
sns.set_context('talk')

sns.relplot(x = 'Potential', y = 'ValueNumeric', hue = 'PreferredFoot', col = 'Position', col_wrap = 4, palette = 'tab10', alpha = .2, data = fifa_nomissing)

# %%
# There seems to be a nonlinear relationship between a player's potential and their value, and this non-linearity is 
# visible across player position and preferred foot.
