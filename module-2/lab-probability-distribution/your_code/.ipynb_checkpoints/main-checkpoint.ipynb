# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import math

# %% [markdown]
# # Challenge 1 - Generate and Plot Normal Distributions

# %% [markdown]
# #### Step 1: Generate samples and test normal distribution
#
# Use mean=50, standard_deviation=5, and sample_size=[10, 50, 500, 5000] to generate 4 random samples that are normally distributed. Test your normal distributions with [`scipy.stats.normaltest`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html).
#
#
# *Hint: Read the documentation for `scipy.stats.normaltest`. The function does not simply return Yes or No for whether your data is normal distribution. It returns the likelihood.*

# %%
mu = 50
sigma = 5

sample_size = pd.Series([10, 50, 500, 5000, 50000])

distributions = sample_size.apply(lambda x: np.random.normal(mu, sigma, x))

tests = distributions.apply(lambda x: stats.normaltest(x))

tests
# Out:
# 0    (2.4788975869876864, 0.2895437723724387)
# 1    (3.632775096334119, 0.16261211963149724)
# 2    (0.9345323001383945, 0.6267132684337609)
# 3    (1.0922971044992325, 0.5791761870643892)
# 4    (2.3704559621839687, 0.3056764830958725)
# dtype: object

# %% [markdown]
# #### Interpret the normaltest results and make your observations.

# %%
# in the current set of random samples, the chi-square fit statistics range from .93 and 2.48, 
# all of which result in p-values larger than the standard .05 cutoff for rejection of the null. 
# since the null hypothesis for this test is that the distribution is normal and we do not have 
# enough evidence to suggest otherwise, so we can assume that the all of the distributions 
# created are approximately normal.

# %% [markdown]
# #### Step 2: Plot normal distributions
#
# Use matplotlib subplots to plot a histogram of each sample.
#
# *Hints:*
# - Use subplots to compare your figures side by side.
#
# - Your output should look like below:
#
# ![normal distributions with different sample sizes](ch-1.png)

# %%
fig, ax = plt.subplots(1, 4)

f.set_figwidth(15)

f.subplots_adjust(wspace=1)

for i in range(0, 4):
    ax[i].set_title('n=%s' % (sample_size[i]))
    count, bins, ignored = ax[i].hist(dists[i], 20, density=True)

# %%
fig, ax = plt.subplots(1, 5, figsize = (20, 5))

for i in range(sample_size.size):
    n = sample_size[i]
    sns.distplot(distributions[i], kde = True, ax = ax[i])
    ax[i].set_title(f'n = {n}')

fig.subplots_adjust(hspace = 0, wspace = .5)

# %% [markdown]
# #### Compare the distributions above. What do you observe? Explain with the Central Limit Theorem.

# %% [markdown]
# # Challenge 2 - Plot Probability Mass Function (PMF)

# %% [markdown]
# #### Background knowledge
#
# [PMF](https://en.wikipedia.org/wiki/Probability_mass_function) shows the probability distribution of a **discrete random variable**. A [discrete random variable](https://en.wikipedia.org/wiki/Random_variable#Discrete_random_variable) has random numeric values that are not continuous. For example, the number of people in a household can only be integers but not floats. Therefore the number of people in a household is a discrete variable.
#
# #### Question: We assume that the probability of clicking an Ad in a Youtube video is 0.15. We have a sample of 5 people who wathched the video and we want to plot the PMF for a binomial distribution.
#
# *Hint: use binom from `scipy.stats.binom`. Your output should look like below:*
#
# ![binom 10](ch-2.png)

# %%
# Your code here
from scipy.stats import binom

n, p = 5, 0.15

x = range(n)

dist = binom(n, p)

fig, ax = plt.subplots(1, 1)

plt.plot(x, dist.pmf(x))

plt.show()

# %% [markdown]
# #### Explain what you observe from the plot above

# %%
# Your comment here

# %% [markdown]
# #### Now plot PMP with 50, 500, and 5000 visitors.

# %%
# Your code here

# %% [markdown]
# #### What did you notice from the distribution plots? Comment your findings.

# %%
# Your comment here

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Reaserch the Poisson distribution. Write about your own understanding of the Poisson distribution.

# %%
# Your comment here

# %% [markdown]
# #### A website has an average of 300 visits per day. What is the probability of getting 320 visitors in a day?
#
# *Hint: use `scipy.stats.poisson`*

# %%
# Your code here

# %% [markdown]
# #### What is the probability of getting 60 visits?

# %%
# Your code here

# %% [markdown]
# #### Plot the distribution of the probability for getting 0-1000 visits.
#
# *Hints:*
#
# - Create a list to store the Poisson distribution probabilities for n=0 to 1000. Then plot the probabilities.
#
# - Your plot should look like below:
#
# ![poisson distribution](ch-3.png)

# %%
# your code here
from scipy.stats import poisson

N = np.arange(1000)

rv = poisson(300)

arr = []

for n in N:
    arr.append(rv.pmf(n))

plt.plot(arr)
