# %%
import feedparser as fp
import pandas as pd

# %%
url = 'http://feeds.bbci.co.uk/news/rss.xml'

# %%
rss = fp.parse(url)

# %%
rss.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
rss.entries
# Out:
# [{'title': 'PC Andrew Harper: Three teenagers charged with murder',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://feeds.bbci.co.uk/news/rss.xml',
#    'value': 'PC Andrew Harper: Three teenagers charged with murder'},
#   'summary': 'PC Andrew Harper died after he was dragged along a road by a vehicle in Berkshire last month.',
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://feeds.bbci.co.uk/news/rss.xml',
#    'value': 'PC Andrew Harper died after he was dragged along a road by a vehicle in Berkshire last month.'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.bbc.co.uk/news/uk-england-49746155'}],
#   'link': 'https://www.bbc.co.uk/news/uk-england-49746155',
#   'id': 'https://www.bbc.co.uk/news/uk-england-49746155',
#   'guidislink': False,
#   'published': 'Wed, 18 Sep 2019 14:50:09 GMT',
# ...

# %%
rss.entries[0]['title']
# Out:
# 'PC Andrew Harper: Three teenagers charged with murder'

# %%
[i['title'] for i in rss.entries]
# Out:
# ['PC Andrew Harper: Three teenagers charged with murder',
#  "Gareth Thomas: Journalist 'told rugby player's parents of HIV'",
#  "Saudi Arabia presents 'oil attacks evidence'",
#  "British Airways pilots call off next week's strike",
#  "Wife cleared of husband's 'mercy killing' murder",
#  'John Humphrys to host his final edition of Radio 4 Today programme',
#  'Liberia school fire leaves many children dead near Monrovia',
#  'Scalesceugh Hall: Firefighters tackle blaze at mansion',
#  "Inside Afghanistan's 'no-man's land'",
#  "Worker dies on Waterloo station's moving walkway",
#  "India e-cigarettes: Ban announced to prevent youth 'epidemic'",
#  "RuPaul's Drag Race UK hits the pink carpet",
#  'Injured seagull photographed with arrow embedded in head in Elgin',
#  'Lord of the Rings returns to New Zealand with Amazon TV show',
#  'Boris Johnson confronted on east London hospital visit',
#  'Albanians and Serbs remain divided after the War',
# ...

# %%
pd.DataFrame(rss.entries)
